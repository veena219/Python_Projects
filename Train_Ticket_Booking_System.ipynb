# %%
from datetime import datetime
startAgain=("yes")
while startAgain!=("no","NO","No"):
    print("\nTRAIN TICKET BOOKING ONLINE")
    print("\n1. Train Ticket Booking")
    print("\n2. Check PNR  status")
    print("\n3. Ticket Cancellation")
    a=int(input("\nChoose one from the above:"))
    if a==1:
        print("Train Ticket Booking")
        b=input("\nFrom Station/City:")
        c=input("To Station/City:")
        string=str(input("Enter date(yyyy-mm-dd hh:mm):"))
        date=datetime.strptime(string,"%Y-%m-%d %H:%M")
        print(date)
        print("\nSearch Trains....")
        print("1. Uday Express 2. Super Express")
        d=int(input("\nselect train:"))
        if d==1:
            print("\nUday Express-10011")
            print(b,"To",c)
            print("1. SL-Rs.635")
            print("2. 3A-Rs.1550") 
            print("3. 2A-Rs.2700") 
            print("4. 1A-Rs.4000")
            e=int(input("\nEnter your option:"))
            if e==1:
                f=int(input("\nEnter your mobile number:"))
                g=int(input("Enter no of ticket you want:"))
                h=[]
                j=[]
                k=[]
                for i in range(g):
                    name=str(input("\nName:"))
                    h.append(name)
                    age=input("Age:")
                    j.append(age)
                    gender=str(input("Gender:"))
                    k.append(gender)
                m=0
                for l in range(g):
                    print("\nUday Express-10011")
                    print(b,"To",c)
                    print(date)
                    print("SL-Rs.635")
                    print("Name:",h[m])
                    print("age:",j[m])
                    print("Gender:",k[m])
                    m=m+1
                n=input("\nDo you want to take Travel Insurance??(yes/no):")
                o=input("I agree to the Cancellation & Refund Policy:")
                if o=="yes":
                    print("\n\nPROCEED TO PAYMENT")
                else:
                    print("Inavalid Option")
                    break
            
                print("PAY AMOUNT:",635*g)
                print("\nPayment Options:")
                print("1.Google Pay \n2.Debit/Credit/ATM Card")
                q=int(input("\nEnter the payment option:"))
                if q==1:
                    print("SORRY!\nWe were unable to process your payment.Please try again later..")
                else:
                    print("SORRY!\nWe were unable to process your payment.Please try again later..")
            elif e==2:
                print("3rd AC Coach not available")
            elif e==3:
                print("2nd AC Coach not available")
            elif e==4:
                print("1st AC Coach not available")
        elif d==2:
            print("NOT AVAILABLE")
        startAgain=input("\nAnything else you want to check again??:")
        if startAgain in ("YES","yes","Y","y"):
            startAgain=("yes")
        else:
            print("\nThank You \nHave a nice day!!")
            break
    elif a==2:
        print("\nCheck PNR  status")
        t=str(input("\nPNR Numner:"))
        u=int(input("Train Number:"))
        if len(t)==10:
            print("\nIncorrect PNR Number")
        else:
            print("\nInvalid Input")
        startAgain=input("\nAnything else you want to check again??:")
        if startAgain in ("YES","yes","Y","y"):
            startAgain=("yes")
        else:
            print("\nThank You")
            break
    elif a==3:
        print("\nTicket Cancellation")
        x=int(input("\nTrain Number:"))
        y=input("PNR number:")
        z=input("Are you sure you want to cancel your ticket??\nAll cancelations are final and cannot be charged:")
        if z=="yes":
            print("\nTicket cancelled")
        else:
            print("Ticket not cancelled")
        startAgain=input("\nAnything else you want to check again??:")
        if startAgain in ("YES","yes","Y","y"):
            startAgain=("yes")
        else:
            print("\nThank You")
            break
